# %% [markdown]
# # Practical Statistics for Data Scientists (Python)
#
# ## Chapter 1. Exploratory Data Analysis
#
# > 2020 Peter C. Bruce, Andrew Bruce, Peter Gedeck
#
# Now that we have some basic pandas under our belt, it's time to put them into an analytical workflow that should always begin with Exploratory Data Analysis (EDA).
#
# Use this notebook as you read through chapter 1. in _Practical Statistics_, so you can learn more about the basic statistical analyses that help you "read" your data.

# %% [markdown]
# ## 1. What's Exploratory Data Analysis (EDA)?

# %% [markdown]
# <figure style="float:left;margin-right:2rem;width:500px">
# <img style="border:solid black 1px;border-radius:7px;" src="../images/3.5-eda-cheatsheet.jpg">
# <figcaption style="font-size:8px">Original image src: <a href="https://towardsdatascience.com/semi-automated-exploratory-data-analysis-eda-in-python-7f96042c9809">Destin Gong</a></figcaption>
# </figure>
# EDA is essentially the method by which to shore up a birds-eye view of the data. Think of it like scanning a texts main headings to glean what it's about, what may be of interest, and also your first critical sense about what you think may be missing or wrong with it. Some typical goals include:
#
# - Summarize its main characteristics
# - Identify potential anomalies, errors, or relationships/patterns aomong variables
# - Squash/test some assumptions about data
#
# We will follow some of the common and basic EDA analytical and visualization techniques reviewed in the assigned text (Bruce, Bruce & Gedeck, 2020):
#
# 1. Estimates of Location
# 2. Estimates of Variability
# 3. Distribution
# 4. Exploring Binary and Categorical Data Types
# 5. Correlation
# 6. Exploring Two or More Variables

# %% [markdown]
# ## 2. Project Setup

# %% [markdown]
# ### 2.1 Imports

# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
from scipy.stats import trim_mean
from statsmodels import robust
import wquantiles

import seaborn as sns
import matplotlib.pylab as plt

import seaborn as sns 
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline 
sns.set(color_codes=True)

pd.options.display.max_rows = 100

# %% [markdown]
# ### 2.2 Import the Files
#
# Use the following cells to "read" in the files located in the `prac_stats` folder for use in this notebook:
#
# - airline_stats.csv
# - kc_tax.csv.gz
# - lc_loans.csv
# - dfw_airline.csv
# - sp500_data.csv.gz
#   - (this one takes awhile to upload)
# - sp500_sectors.csv
# - state.csv

# %% [markdown]
# ### 2.3 Define paths to data sets

# %% [markdown]
# Sometimes it's best to define your paths to data up top, if you have more than a few. It's not too typical to have so many though, since it's mainly for educational/demo purposes.

# %%
data_path = './../data/prac-stats/'
AIRLINE_STATS_CSV = data_path+'airline_stats.csv'
KC_TAX_CSV = data_path+'kc_tax.csv.gz'
LC_LOANS_CSV = data_path+'lc_loans.csv'
AIRPORT_DELAYS_CSV = data_path+'dfw_airline.csv'
SP500_DATA_CSV = data_path+'sp500_data.csv.gz'
SP500_SECTORS_CSV = data_path+'sp500_sectors.csv'
STATE_CSV = data_path+'state.csv'

airline_stats = pd.read_csv(AIRLINE_STATS_CSV)
kc_tax = pd.read_csv(KC_TAX_CSV, compression='gzip')
lc_loans = pd.read_csv(LC_LOANS_CSV)
dfw_airline = pd.read_csv(AIRPORT_DELAYS_CSV)

# %% [markdown]
# ## 3. Estimates of Location

# %% [markdown]
# ### 3.1 Example: Location Estimates of Population and Murder Rates

# %%
# Table 1-2
df_state = pd.read_csv(STATE_CSV)
df_state.head(10)
# Out:
#          State  Population  Murder.Rate Abbreviation
# 0      Alabama     4779736          5.7           AL
# 1       Alaska      710231          5.6           AK
# 2      Arizona     6392017          4.7           AZ
# 3     Arkansas     2915918          5.6           AR
# 4   California    37253956          4.4           CA
# 5     Colorado     5029196          2.8           CO
# 6  Connecticut     3574097          2.4           CT
# 7     Delaware      897934          5.8           DE
# 8      Florida    18801310          5.8           FL
# 9      Georgia     9687653          5.7           GA

# %%
df_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         50 non-null     object
#  1   Population    50 non-null     int64
#  2   Murder.Rate   50 non-null     float64
#  3   Abbreviation  50 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# Notice how there are lots of missign values: of the total 20389 rows, the evictions' columns only have 5080 values.
#
# Let's first examine this to better understand it.

# %%
# Look at some null evictions
df_ny_state_city_evictions.loc[df_ny_state_city_evictions['evictions'].isna()][['year','name','evictions']].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> # Look at some null evictions
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> df_ny_state_city_evictions.loc[df_ny_state_city_evictions['evictions'].isna()][['year','name','evictions']].head()
#
# NameError: name 'df_ny_state_city_evictions' is not defined

# %%
# Look at some NOT null evictions
df_ny_state_city_evictions.loc[df_ny_state_city_evictions['evictions'].notna()][['year','name','evictions']].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 17 line 2
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # Look at some NOT null evictions
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> df_ny_state_city_evictions.loc[df_ny_state_city_evictions['evictions'].notna()][['year','name','evictions']].head()
#
# NameError: name 'df_ny_state_city_evictions' is not defined

# %% [markdown]
# Compute the mean, trimmed mean, and median for Population. For `mean` and `median` we can use the _pandas_ methods of the data frame. The trimmed mean requires the `trim_mean` function in _scipy.stats_.

# %%
df_ny_state_city_evictions['population'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df_ny_state_city_evictions['population'].mean()
#
# NameError: name 'df_ny_state_city_evictions' is not defined

# %%
trim_mean(df_ny_state_city_evictions['population'], 0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> trim_mean(df_ny_state_city_evictions['population'], 0.1)
#
# NameError: name 'df_ny_state_city_evictions' is not defined

# %%
df_ny_state_city_evictions['population'].median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> df_ny_state_city_evictions['population'].median()
#
# NameError: name 'df_ny_state_city_evictions' is not defined

# %% [markdown]
# Weighted mean is available with numpy. For weighted median, we can use the specialised package `wquantiles` (https://pypi.org/project/wquantiles/).

# %%
df_ny_state_city_evictions['poverty-rate'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> df_ny_state_city_evictions['poverty-rate'].mean()
#
# NameError: name 'df_ny_state_city_evictions' is not defined

# %%
print(np.average(df_ny_state_city_evictions['poverty-rate'], weights=df_ny_state_city_evictions['population']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> print(np.average(df_ny_state_city_evictions['poverty-rate'], weights=df_ny_state_city_evictions['population']))
#
# NameError: name 'df_ny_state_city_evictions' is not defined

# %%
print(wquantiles.median(state['Murder.Rate'], weights=state['Population']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> print(wquantiles.median(state['Murder.Rate'], weights=state['Population']))
#
# NameError: name 'state' is not defined

# %% [markdown]
# ## 4. Estimates of Variability

# %%
# Table 1-2
state.head(8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 27 line 2
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> # Table 1-2
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> state.head(8)
#
# NameError: name 'state' is not defined

# %%
state.sample(5)
# Out:
#             State  Population  Murder.Rate Abbreviation
# 28  New Hampshire     1316470          0.9           NH
# 38   Rhode Island     1052567          2.4           RI
# 11          Idaho     1567582          2.0           ID
# 34           Ohio    11536504          4.0           OH
# 37   Pennsylvania    12702379          4.8           PA

# %% [markdown]
# ### 3.1 Standard deviation

# %%
state['Population'].std()
# Out:
# 6848235.347401142

# %% [markdown]
# Interquartile range is calculated as the difference of the 75% and 25% quantile.

# %%
print(state['Population'].quantile(0.75) - state['Population'].quantile(0.25))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> print(state['Population'].quantile(0.75) - state['Population'].quantile(0.25))
#
# NameError: name 'state' is not defined

# %% [markdown]
# Median absolute deviation from the median can be calculated with a method in _statsmodels_

# %%
print(robust.scale.mad(state['Population']))
print(abs(state['Population'] - state['Population'].median()).median() / 0.6744897501960817)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 34 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> print(robust.scale.mad(state['Population']))
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> print(abs(state['Population'] - state['Population'].median()).median() / 0.6744897501960817)
#
# NameError: name 'state' is not defined

# %% [markdown]
# ### 3.2 Percentiles and Boxplots

# %% [markdown]
# _Pandas_ has the `quantile` method for data frames.
#
# A quantile is a specific way to define a ranking system for a data set as a means to examine its distribution of values. In other words, is a particular value above or below a set limit. You have probably interacted with quantile bins before, such as a doctor's visit that uses percentiles (1-100) to see where you land in the land of your physical height for instance. There's also quartiles (quarter of a hundred) or deciles (tenths of a hundred).
#
# Let's see how it helps us understand the `state` data set.

# %%
print(state['Murder.Rate'].quantile([0.05, 0.25, 0.5, 0.75, 0.95]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> print(state['Murder.Rate'].quantile([0.05, 0.25, 0.5, 0.75, 0.95]))
#
# NameError: name 'state' is not defined

# %% [markdown]
# The below corresponds with Table 1.4, which

# %%
# Table 1.4
percentages = [0.05, 0.25, 0.5, 0.75, 0.95]
df = pd.DataFrame(state['Murder.Rate'].quantile(percentages))
df.index = [f'{p * 100}%' for p in percentages]
print(df.transpose())
# Out:
#              5.0%  25.0%  50.0%  75.0%  95.0%
# Murder.Rate   1.6  2.425    4.0   5.55   6.51

# %% [markdown]
# As we have learned from previous notebook lessons, _Pandas_ provides a number of basic exploratory plots. Here's a boxplot, which can help people see a 'birds eye view' of the distribution of data.

# %%
ax = (state['Population']/1_000_000).plot.box(figsize=(3, 4))
ax.set_ylabel('Population (millions)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Data Distributions

# %% [markdown]
# ### 5.1 Frequency Table and Histograms

# %% [markdown]
# The `cut` method for _pandas_ data splits the dataset into bins. There are a number of arguments for the method. The following code creates equal sized bins. The method `value_counts` returns a frequency table.

# %%
binnedPopulation = pd.cut(state['Population'], 10)
print(binnedPopulation.value_counts())
# Out:
# (526935.67, 4232659.0]      24
# (4232659.0, 7901692.0]      14
# (7901692.0, 11570725.0]      6
# (11570725.0, 15239758.0]     2
# (15239758.0, 18908791.0]     1
# (18908791.0, 22577824.0]     1
# (22577824.0, 26246857.0]     1
# (33584923.0, 37253956.0]     1
# (26246857.0, 29915890.0]     0
# (29915890.0, 33584923.0]     0
# Name: Population, dtype: int64

# %%
# Table 1.5
binnedPopulation.name = 'binnedPopulation'
df = pd.concat([state, binnedPopulation], axis=1)
df = df.sort_values(by='Population')

groups = []
for group, subset in df.groupby(by='binnedPopulation'):
    groups.append({
        'BinRange': group,
        'Count': len(subset),
        'States': ','.join(subset.Abbreviation)
    })
print(pd.DataFrame(groups))
# Out:
#                    BinRange  Count  \
# 0    (526935.67, 4232659.0]     24
# 1    (4232659.0, 7901692.0]     14
# 2   (7901692.0, 11570725.0]      6
# 3  (11570725.0, 15239758.0]      2
# 4  (15239758.0, 18908791.0]      1
# 5  (18908791.0, 22577824.0]      1
# 6  (22577824.0, 26246857.0]      1
# 7  (26246857.0, 29915890.0]      0
# 8  (29915890.0, 33584923.0]      0
# 9  (33584923.0, 37253956.0]      1
#
#                                               States
# 0  WY,VT,ND,AK,SD,DE,MT,RI,NH,ME,HI,ID,NE,WV,NM,N...
# 1          KY,LA,SC,AL,CO,MN,WI,MD,MO,TN,AZ,IN,MA,WA
# 2                                  VA,NJ,NC,GA,MI,OH
# 3                                              PA,IL
# 4                                                 FL
# 5                                                 NY
# 6                                                 TX
# 7
# 8
# 9                                                 CA

# %% [markdown]
# _Pandas_ also supports histograms for exploratory data analysis.

# %%
ax = (state['Population'] / 1_000_000).plot.hist(figsize=(4, 4))
ax.set_xlabel('Population (millions)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.2 Density Estimates

# %% [markdown]
# Density is an alternative to histograms that can provide more insight into the distribution of the data points. Use the argument `bw_method` to control the smoothness of the density curve.

# %%
ax = state['Murder.Rate'].plot.hist(density=True, xlim=[0, 12], 
                                    bins=range(1,12), figsize=(4, 4))
state['Murder.Rate'].plot.density(ax=ax)
ax.set_xlabel('Murder Rate (per 100,000)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Exploring Binary and Categorical Data

# %%
# Table 1-6
dfw = pd.read_csv(AIRPORT_DELAYS_CSV)
print(100 * dfw / dfw.values.sum())
# Out:
#      Carrier        ATC   Weather  Security    Inbound
# 0  23.022989  30.400781  4.025214  0.122937  42.428079

# %% [markdown]
# _Pandas_ also supports bar charts for displaying a single categorical variable.

# %%
ax = dfw.transpose().plot.bar(figsize=(4, 4), legend=False)
ax.set_xlabel('Cause of delay')
ax.set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation
#
# First read the required datasets

# %%
sp500_sym = pd.read_csv(SP500_SECTORS_CSV)
sp500_px = pd.read_csv(SP500_DATA_CSV, index_col=0)

# %%
# Table 1-7
# Determine telecommunications symbols
telecomSymbols = sp500_sym[sp500_sym['sector'] == 'telecommunications_services']['symbol']

# Filter data for dates July 2012 through June 2015
telecom = sp500_px.loc[sp500_px.index >= '2012-07-01', telecomSymbols]
telecom.corr()
print(telecom)
# Out:
#                    T       CTL       FTR        VZ      LVLT
# 2012-07-02  0.422496  0.140847  0.070879  0.554180 -0.519998
# 2012-07-03 -0.177448  0.066280  0.070879 -0.025976 -0.049999
# 2012-07-05 -0.160548 -0.132563  0.055128 -0.051956 -0.180000
# 2012-07-06  0.342205  0.132563  0.007875  0.140106 -0.359999
# 2012-07-09  0.136883  0.124279 -0.023626  0.253943  0.180000
# ...              ...       ...       ...       ...       ...
# 2015-06-25  0.049342 -1.600000 -0.040000 -0.187790 -0.330002
# 2015-06-26 -0.256586  0.039999 -0.070000  0.029650 -0.739998
# 2015-06-29 -0.098685 -0.559999 -0.060000 -0.504063 -1.360000
# 2015-06-30 -0.503298 -0.420000 -0.070000 -0.523829  0.199997
# 2015-07-01 -0.019737  0.080000 -0.050000  0.355811  0.139999
#
# [754 rows x 5 columns]

# %% [markdown]
# Next we focus on funds traded on major exchanges (sector == 'etf').

# %%
etfs = sp500_px.loc[sp500_px.index > '2012-07-01', 
                    sp500_sym[sp500_sym['sector'] == 'etf']['symbol']]
print(etfs.head())
# Out:
#                  XLI       QQQ       SPY       DIA       GLD    VXX       USO  \
# 2012-07-02 -0.376098  0.096313  0.028223 -0.242796  0.419998 -10.40  0.000000
# 2012-07-03  0.376099  0.481576  0.874936  0.728405  0.490006  -3.52  0.250000
# 2012-07-05  0.150440  0.096313 -0.103487  0.149420  0.239991   6.56 -0.070000
# 2012-07-06 -0.141040 -0.491201  0.018819 -0.205449 -0.519989  -8.80 -0.180000
# 2012-07-09  0.244465 -0.048160 -0.056445 -0.168094  0.429992  -0.48  0.459999
#
#                  IWM       XLE       XLY       XLU       XLB       XTL  \
# 2012-07-02  0.534641  0.028186  0.095759  0.098311 -0.093713  0.019076
# 2012-07-03  0.926067  0.995942  0.000000 -0.044686  0.337373  0.000000
# 2012-07-05 -0.171848 -0.460387  0.306431 -0.151938  0.103086  0.019072
# 2012-07-06 -0.229128  0.206706  0.153214  0.080437  0.018744 -0.429213
# 2012-07-09 -0.190939 -0.234892 -0.201098 -0.035751 -0.168687  0.000000
#
#                  XLV       XLP       XLF       XLK
# 2012-07-02 -0.009529  0.313499  0.018999  0.075668
# 2012-07-03  0.000000  0.129087  0.104492  0.236462
# 2012-07-05 -0.142955 -0.073766 -0.142490  0.066211
# 2012-07-06 -0.095304  0.119865  0.066495 -0.227003
# 2012-07-09  0.352630 -0.064548  0.018999  0.009457

# %% [markdown]
# Due to the large number of columns in this table, looking at the correlation matrix is cumbersome and it's more convenient to plot the correlation as a heatmap. The _seaborn_ package provides a convenient implementation for heatmaps.

# %%
fig, ax = plt.subplots(figsize=(5, 4))
ax = sns.heatmap(etfs.corr(), vmin=-1, vmax=1, 
                 cmap=sns.diverging_palette(20, 220, as_cmap=True),
                 ax=ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# The above heatmap works when you have color. For the greyscale images, as used in the book, we need to visualize the direction as well. The following code shows the strength of the correlation using ellipses.

# %%
from matplotlib.collections import EllipseCollection
from matplotlib.colors import Normalize

def plot_corr_ellipses(data, figsize=None, **kwargs):
    ''' https://stackoverflow.com/a/34558488 '''
    M = np.array(data)
    if not M.ndim == 2:
        raise ValueError('data must be a 2D array')
    fig, ax = plt.subplots(1, 1, figsize=figsize, subplot_kw={'aspect':'equal'})
    ax.set_xlim(-0.5, M.shape[1] - 0.5)
    ax.set_ylim(-0.5, M.shape[0] - 0.5)
    ax.invert_yaxis()

    # xy locations of each ellipse center
    xy = np.indices(M.shape)[::-1].reshape(2, -1).T

    # set the relative sizes of the major/minor axes according to the strength of
    # the positive/negative correlation
    w = np.ones_like(M).ravel() + 0.01
    h = 1 - np.abs(M).ravel() - 0.01
    a = 45 * np.sign(M).ravel()

    ec = EllipseCollection(widths=w, heights=h, angles=a, units='x', offsets=xy,
                           norm=Normalize(vmin=-1, vmax=1),
                           transOffset=ax.transData, array=M.ravel(), **kwargs)
    ax.add_collection(ec)

    # if data is a DataFrame, use the row/column names as tick labels
    if isinstance(data, pd.DataFrame):
        ax.set_xticks(np.arange(M.shape[1]))
        ax.set_xticklabels(data.columns, rotation=90)
        ax.set_yticks(np.arange(M.shape[0]))
        ax.set_yticklabels(data.index)

    return ec

m = plot_corr_ellipses(etfs.corr(), figsize=(5, 4), cmap='bwr_r')
cb = fig.colorbar(m)
cb.set_label('Correlation coefficient')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatterplots
# Simple scatterplots are supported by _pandas_. Specifying the marker as `$\u25EF$` uses an open circle for each point.

# %%
ax = telecom.plot.scatter(x='T', y='VZ', figsize=(4, 4), marker='$\u25EF$')
ax.set_xlabel('ATT (T)')
ax.set_ylabel('Verizon (VZ)')
ax.axhline(0, color='grey', lw=1)
ax.axvline(0, color='grey', lw=1)

plt.tight_layout()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
ax = telecom.plot.scatter(x='T', y='VZ', figsize=(4, 4), marker='$\u25EF$', alpha=0.5)
ax.set_xlabel('ATT (T)')
ax.set_ylabel('Verizon (VZ)')
ax.axhline(0, color='grey', lw=1)
print(ax.axvline(0, color='grey', lw=1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 67 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> ax = telecom.plot.scatter(x='T', y='VZ', figsize=(4, 4), marker='$\u25EF$', alpha=0.5)
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y123sZmlsZQ%3D%3D?line=1'>2</a> ax.set_xlabel('ATT (T)')
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y123sZmlsZQ%3D%3D?line=2'>3</a> ax.set_ylabel('Verizon (VZ)')
#
# NameError: name 'telecom' is not defined

# %% [markdown]
# ## 7. Exploring Two or More Variables

# %% [markdown]
# Load the kc_tax dataset and filter based on a variety of criteria

# %%
kc_tax = pd.read_csv(KC_TAX_CSV)
kc_tax0 = kc_tax.loc[(kc_tax.TaxAssessedValue < 750000) & 
                     (kc_tax.SqFtTotLiving > 100) &
                     (kc_tax.SqFtTotLiving < 3500), :]
print(kc_tax0.shape)
# Out:
# (432693, 3)

# %% [markdown]
# ### 7.1 Hexagonal binning and Contours

# %% [markdown]
# #### Plotting numeric versus numeric data

# %% [markdown]
# If the number of data points gets large, scatter plots will no longer be meaningful. Here methods that visualize densities are more useful. The `hexbin` method for _pandas_ data frames is one powerful approach.

# %%
ax = kc_tax0.plot.hexbin(
    x='SqFtTotLiving', 
    y='TaxAssessedValue',
    gridsize=30, 
    sharex=False, 
    figsize=(5, 4))
ax.set_xlabel('Finished Square Feet')
ax.set_ylabel('Tax Assessed Value')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 74 line 1
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y133sZmlsZQ%3D%3D?line=0'>1</a> ax = kc_tax0.plot.hexbin(
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y133sZmlsZQ%3D%3D?line=1'>2</a>     x='SqFtTotLiving',
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y133sZmlsZQ%3D%3D?line=2'>3</a>     y='TaxAssessedValue',
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y133sZmlsZQ%3D%3D?line=3'>4</a>     gridsize=30,
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y133sZmlsZQ%3D%3D?line=4'>5</a>     sharex=False,
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y133sZmlsZQ%3D%3D?line=5'>6</a>     figsize=(5, 4))
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y133sZmlsZQ%3D%3D?line=6'>7</a> ax.set_xlabel('Finished Square Feet')
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y133sZmlsZQ%3D%3D?line=7'>8</a> ax.set_ylabel('Tax Assessed Value')
#
# NameError: name 'kc_tax0' is not defined

# %% [markdown]
# The _seaborn_ kdeplot is a two-dimensional extension of the density plot. The calculation of the 2D-density for the full dataset takes several minutes. It is sufficient to create the visualization with a smaller sample of the dataset. With 10,000 data points, creating the graph takes only seconds. While some details may be lost, the overall shape is preserved.

# %%
fig, ax = plt.subplots(figsize=(4, 4))
sns.kdeplot(data=kc_tax0.sample(10000), x='SqFtTotLiving', y='TaxAssessedValue', ax=ax)
ax.set_xlabel('Finished Square Feet')
ax.set_ylabel('Tax Assessed Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.2 Two Categorical Variables

# %% [markdown]
# Load the `lc_loans` dataset

# %%
lc_loans = pd.read_csv(LC_LOANS_CSV)

# %%
# Table 1-8(1)
crosstab = lc_loans.pivot_table(index='grade', columns='status', 
                                aggfunc=lambda x: len(x), margins=True)
print(crosstab)
# Out:
# status  Charged Off  Current  Fully Paid  Late     All
# grade
# A              1562    50051       20408   469   72490
# B              5302    93852       31160  2056  132370
# C              6023    88928       23147  2777  120875
# D              5007    53281       13681  2308   74277
# E              2842    24639        5949  1374   34804
# F              1526     8444        2328   606   12904
# G               409     1990         643   199    3241
# All           22671   321185       97316  9789  450961

# %%
# Table 1-8(2)
df = crosstab.copy().loc['A':'G',:]
df.loc[:,'Charged Off':'Late'] = df.loc[:,'Charged Off':'Late'].div(df['All'], axis=0)
df['All'] = df['All'] / sum(df['All'])
perc_crosstab = df
print(perc_crosstab)
# Out:
# status  Charged Off   Current  Fully Paid      Late       All
# grade
# A          0.021548  0.690454    0.281528  0.006470  0.160746
# B          0.040054  0.709013    0.235401  0.015532  0.293529
# C          0.049828  0.735702    0.191495  0.022974  0.268039
# D          0.067410  0.717328    0.184189  0.031073  0.164708
# E          0.081657  0.707936    0.170929  0.039478  0.077177
# F          0.118258  0.654371    0.180409  0.046962  0.028614
# G          0.126196  0.614008    0.198396  0.061401  0.007187

# %% [markdown]
# ### 7.3 Categorical and Numeric Data
#
# _Pandas_ boxplots of a column can be grouped by a different column.

# %%
airline_stats = pd.read_csv(AIRLINE_STATS_CSV)
airline_stats.head()
ax = airline_stats.boxplot(by='airline', column='pct_carrier_delay',
                           figsize=(5, 5))
ax.set_xlabel('')
ax.set_ylabel('Daily % of Delayed Flights')
plt.suptitle('')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# _Pandas_ also supports a variation of boxplots called _violinplot_.

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.violinplot(data=airline_stats, x='airline', y='pct_carrier_delay',
               ax=ax, inner='quartile', color='white')
ax.set_xlabel('')
ax.set_ylabel('Daily % of Delayed Flights')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.4 Visualizing Multiple Variables

# %%
zip_codes = [98188, 98105, 98108, 98126]
kc_tax_zip = kc_tax0.loc[kc_tax0.ZipCode.isin(zip_codes),:]
kc_tax_zip

def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=25, cmap=cmap, **kwargs)

g = sns.FacetGrid(kc_tax_zip, col='ZipCode', col_wrap=2)
g.map(hexbin, 'SqFtTotLiving', 'TaxAssessedValue', 
      extent=[0, 3500, 0, 700000])
g.set_axis_labels('Finished Square Feet', 'Tax Assessed Value')
g.set_titles('Zip code {col_name:.0f}')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb Cell 87 line 2
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y152sZmlsZQ%3D%3D?line=0'>1</a> zip_codes = [98188, 98105, 98108, 98126]
# ----> <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y152sZmlsZQ%3D%3D?line=1'>2</a> kc_tax_zip = kc_tax0.loc[kc_tax0.ZipCode.isin(zip_codes),:]
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y152sZmlsZQ%3D%3D?line=2'>3</a> kc_tax_zip
#       <a href='vscode-notebook-cell:/Users/kim/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/05-Pandas-EDA-Overview-Practical-Stats.ipynb#Y152sZmlsZQ%3D%3D?line=4'>5</a> def hexbin(x, y, color, **kwargs):
#
# NameError: name 'kc_tax0' is not defined
